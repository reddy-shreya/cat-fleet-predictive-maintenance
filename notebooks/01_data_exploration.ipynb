# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\reddy\Downloads\archive (1)\synthetic_telemetry_data.csv")
print(df.shape)
print(df["vehicle_id"].nunique())
print(df["failure_type"].value_counts(dropna=False))
# Out:
# (1970, 41)
# 50
# failure_type
# No Failure             1935
# Brake Pad Worn            9
# Low Brake Fluid           5
# Battery Dead              4
# Engine Overheat           4
# Battery Drain             4
# Low Battery Voltage       4
# Excessive Vibration       2
# Brake Overheat            2
# Low Oil Pressure          1
# Name: count, dtype: int64
